# %%
import pandas as pd
dateparse = lambda dates: pd.to_datetime(dates, format='%Y-%m-%d')
data = pd.read_excel('Copy of brentcrudeoil (1).xlsx', parse_dates=['Date'], index_col='Date', date_parser=dateparse)
# Out:
# C:\Users\Swatama Mega Teknik\AppData\Local\Temp\ipykernel_556\331428761.py:3: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   data = pd.read_excel('Copy of brentcrudeoil (1).xlsx', parse_dates=['Date'], index_col='Date', date_parser=dateparse)

# %%
data.head(10)
# Out:
#                          Close  chg(close)    Low  chg(low)   High  chg(high)
# Date
# 2021-01-04 23:57:59.904  50.23       50.23  49.97     49.97  51.88      51.88
# 2021-01-05 23:57:59.904  51.87        1.64  50.01      0.04  52.26       0.38
# 2021-01-06 23:57:59.904  52.02        0.15  51.21      1.20  52.37       0.11
# 2021-01-07 23:57:59.904  52.20        0.18  51.89      0.68  52.34      -0.03
# 2021-01-08 23:57:59.904  53.33        1.13  52.31      0.42  53.61       1.27
# 2021-01-11 23:57:59.904  53.33        0.00  52.66      0.35  53.48      -0.13
# 2021-01-12 23:57:59.904  54.12        0.79  53.35      0.69  54.23       0.75
# 2021-01-13 23:57:59.904  54.13        0.01  53.75      0.40  54.82       0.59
# 2021-01-14 23:57:59.904  54.43        0.30  53.68     -0.07  54.56      -0.26
# 2021-01-15 23:57:59.904  53.53       -0.90  52.97     -0.71  54.50      -0.06

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(data.index, data['Close'])
ax.set_xlabel("Date")
ax.set_ylabel("Value")
# Out:
# Text(0, 0.5, 'Value')
